# %%
import pandas as pd
import os

os.chdir("../data/raw_data/gems/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-208-dc6db812e857> in <module>
#       2 import os
#       3
# ----> 4 os.chdir("../data/raw_data/gems/")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw_data/gems/'

# %%
ls
# Out:
# 2018_I10gem.txt                 icd10OrderFiles.pdf
# 2018_I9gem.txt                  icd10_descriptions.zip
# CMS32_DESC_LONG_DX.txt          icd10_gems.zip
# CMS32_DESC_LONG_SG.txt          icd10cmCodesFile.pdf
# CMS32_DESC_LONG_SHORT_DX.xlsx   icd10cm_codes_2018.txt
# CMS32_DESC_LONG_SHORT_SG.xlsx   icd10cm_codes_addenda_2018.txt
# CMS32_DESC_SHORT_DX.txt         icd10cm_order_2018.txt
# CMS32_DESC_SHORT_SG.txt         icd10cm_order_addenda_2018.txt
# Dxgem_guide_2018.pdf            icd9_descriptions.zip
# GemsTechDoc_2018.pdf

# %%
filename = "2018_I10gem.txt"

# %%
filename = f"{filename.split('.')[0]}.csv"

# %%
filename
# Out:
# '2018_I10gem.csv'

# %%
def format_icd(filename: str):
    
    df = pd.read_csv("2018_I10gem.txt", 
                     sep="[\s]{1,}",
                     names=["source", "target", "flags"],
                     encoding="latin-1")
    
    save_name = update_file_name(filename)
    df.to_csv(save_name)
    
    
def update_file_name(filename: str):
    
    return f"{filename.split('.')[0]}.csv"
    
    

def format_desc(filename: str, codetype: str, separater: str = ","):
    
    df = pd.read_csv(filename,names=[codetype], sep = separater, encoding="latin-1")
    
    df[[codetype, f"{codetype}_desc"]] = df[codetype].str.split(" ", 1, expand=True)
    
    save_name = update_file_name(filename)
    df.to_csv(save_name, index = False)

# %%
format_icd("2018_I10gem.txt")
format_icd("2018_I9gem.txt")

format_desc("CMS32_DESC_LONG_DX.txt", "icd9", separater = ",")
format_desc("icd10cm_codes_2018.txt", "icd10", separater = "//s")
# Out:
# /Users/patricklong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /Users/patricklong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
read_icd("2018_I10gem.txt").to_csv("2018_I10gem.csv")
df_icd10_9 = read_icd("2018_I9gem.txt")

icd9_desc= read_desc("CMS32_DESC_LONG_DX.txt", "icd9", separater = ",")
icd10_desc = read_desc("icd10cm_codes_2018.txt", "icd10", separater = "//s")
# Out:
# /Users/patricklong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /Users/patricklong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_icd9_10 = read_icd("2018_I10gem.txt")
df_icd10_9 = read_icd("2018_I9gem.txt")

icd9_desc= read_desc("CMS32_DESC_LONG_DX.txt", "icd9", separater = ",")
icd10_desc = read_desc("icd10cm_codes_2018.txt", "icd10", separater = "//s")
# Out:
# /Users/patricklong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /Users/patricklong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.

# %%
ls
# Out:
# 2018_I10gem.txt                 icd10OrderFiles.pdf
# 2018_I9gem.txt                  icd10_descriptions.zip
# CMS32_DESC_LONG_DX.txt          icd10_gems.zip
# CMS32_DESC_LONG_SG.txt          icd10cmCodesFile.pdf
# CMS32_DESC_LONG_SHORT_DX.xlsx   icd10cm_codes_2018.txt
# CMS32_DESC_LONG_SHORT_SG.xlsx   icd10cm_codes_addenda_2018.txt
# CMS32_DESC_SHORT_DX.txt         icd10cm_order_2018.txt
# CMS32_DESC_SHORT_SG.txt         icd10cm_order_addenda_2018.txt
# Dxgem_guide_2018.pdf            icd9_descriptions.zip
# GemsTechDoc_2018.pdf

# %%
pwd
# Out:
# '/Users/patricklong/Desktop/github_repos/HealthDataTools/data/raw_data/gems'

# %%
df = pd.read_csv("icd9_gems_lookup.csv")

# %%
def get_icd_description(icd_code: str, icd_revision: str):

# %%
df.head()
# Out:
#   source target  flags  icd9                               icd9_desc
# 0   0010   A000      0  0010          Cholera due to vibrio cholerae
# 1   0011   A001      0  0011   Cholera due to vibrio cholerae el tor
# 2   0019   A009      0  0019                                 Cholera
# 3   0020  A0100  10000  0020                           Typhoid fever
# 4   0021   A011      0  0021                     Paratyphoid fever A

# %%
def icd9_to_icd10(icd_code: str):
    
    lookup_table = pd.read_csv("icd9_gems_lookup.csv")

    
    return lookup_table[lookup_table["source"] == icd_code]

# %%
v = icd9_to_icd10("0010")

# %%
v.head()
# Out:
#   source target  flags icd10  \
# 0   0010   A000      0  A000
#
#                                           icd10_desc
# 0     Cholera due to Vibrio cholerae 01, biovar c...

# %%
df[df["source"] == "0010"].loc[:,["icd9","icd9_desc"]]
# Out:
#    icd9                        icd9_desc
# 0  0010   Cholera due to vibrio cholerae

# %%
v = convert_by_gems("0010", 10)

# %%
v
# Out:
# Empty DataFrame
# Columns: [flags]
# Index: []

# %%
def get_icd10(icd_code: str):

# %%
df
# Out:
#       source  target  flags   icd9  \
# 0       0010    A000      0   0010
# 1       0011    A001      0   0011
# 2       0019    A009      0   0019
# 3       0020   A0100  10000   0020
# 4       0021    A011      0   0021
# 5       0022    A012      0   0022
# 6       0023    A013      0   0023
# 7       0029    A014      0   0029
# 8       0030    A020      0   0030
# 9       0031    A021  10000   0031
# 10     00320   A0220      0  00320
# 11     00321   A0221      0  00321
# 12     00322   A0222      0  00322
# 13     00323   A0223      0  00323
# 14     00324   A0224      0  00324
# 15     00329   A0229  10000  00329
# 16      0038    A028      0   0038
# 17      0039    A029      0   0039
# 18      0040    A030      0   0040
# 19      0041    A031      0   0041
# 20      0042    A032      0   0042
# 21      0043    A033      0   0043
# 22      0048    A038      0   0048
# 23      0049    A039      0   0049
# 24      0050    A050      0   0050
# 25      0051    A051      0   0051
# 26      0052    A052      0   0052
# 27      0053    A058  10000   0053
# 28      0054    A053      0   0054
# 29     00581    A055      0  00581
# ...      ...     ...    ...    ...
# 24830  V9009   Z1809      0  V9009
# 24831  V9010   Z1810      0  V9010
# 24832  V9011   Z1811      0  V9011
# 24833  V9012   Z1812      0  V9012
# 24834   V902    Z182      0   V902
# 24835  V9031   Z1831      0  V9031
# 24836  V9032   Z1832      0  V9032
# 24837  V9033   Z1833      0  V9033
# 24838  V9039   Z1839      0  V9039
# 24839  V9081   Z1881      0  V9081
# 24840  V9083   Z1883      0  V9083
# 24841  V9089   Z1889      0  V9089
# 24842   V909    Z189      0   V909
# 24843  V9100  O30009  10000  V9100
# 24844  V9101  O30019  10000  V9101
# 24845  V9102  O30039  10000  V9102
# 24846  V9103  O30049  10000  V9103
# 24847  V9109  O30099  10000  V9109
# 24848  V9110  O30109  10000  V9110
# 24849  V9111  O30119  10000  V9111
# 24850  V9112  O30129  10000  V9112
# 24851  V9119  O30199  10000  V9119
# 24852  V9120  O30209  10000  V9120
# 24853  V9121  O30219  10000  V9121
# 24854  V9122  O30229  10000  V9122
# 24855  V9129  O30299  10000  V9129
# 24856  V9190  O30809  10000  V9190
# 24857  V9191  O30819  10000  V9191
# 24858  V9192  O30829  10000  V9192
# 24859  V9199  O30899  10000  V9199
#
#                                                icd9_desc
# 0                         Cholera due to vibrio cholerae
# 1                  Cholera due to vibrio cholerae el tor
# 2                                                Cholera
# 3                                          Typhoid fever
# 4                                    Paratyphoid fever A
# 5                                    Paratyphoid fever B
# 6                                    Paratyphoid fever C
# 7                                      Paratyphoid fever
# 8                             Salmonella gastroenteritis
# 9                                  Salmonella septicemia
# 10                        Localized salmonella infection
# 11                                 Salmonella meningitis
# 12                                  Salmonella pneumonia
# 13                                  Salmonella arthritis
# 14                              Salmonella osteomyelitis
# 15                 Other localized salmonella infections
# 16                 Other specified salmonella infections
# 17                                  Salmonella infection
# 18                                  Shigella dysenteriae
# 19                                     Shigella flexneri
# 20                                       Shigella boydii
# 21                                       Shigella sonnei
# 22                   Other specified shigella infections
# 23                                           Shigellosis
# 24                         Staphylococcal food poisoning
# 25                               Botulism food poisoning
# 26      Food poisoning due to Clostridium perfringens...
# 27                Food poisoning due to other Clostridia
# 28         Food poisoning due to Vibrio parahaemolyticus
# 29               Food poisoning due to Vibrio vulnificus
# ...                                                  ...
# 24830               Other retained radioactive fragments
# 24831                           Retained metal fragments
# 24832                  Retained magnetic metal fragments
# 24833               Retained nonmagnetic metal fragments
# 24834                         Retained plastic fragments
# 24835                   Retained animal quills or spines
# 24836                                     Retained tooth
# 24837                            Retained wood fragments
# 24838                   Other retained organic fragments
# 24839                           Retained glass fragments
# 24840            Retained stone or crystalline fragments
# 24841              Other specified retained foreign body
# 24842                              Retained foreign body
# 24843                                     Twin gestation
# 24844                                     Twin gestation
# 24845                                     Twin gestation
# 24846                                     Twin gestation
# 24847                                     Twin gestation
# 24848                                  Triplet gestation
# 24849                                  Triplet gestation
# 24850                                  Triplet gestation
# 24851                                  Triplet gestation
# 24852                               Quadruplet gestation
# 24853                               Quadruplet gestation
# 24854                               Quadruplet gestation
# 24855                               Quadruplet gestation
# 24856                 Other specified multiple gestation
# 24857                 Other specified multiple gestation
# 24858                 Other specified multiple gestation
# 24859                 Other specified multiple gestation
#
# [24860 rows x 5 columns]

# %%
def read_tables():

    df_icd9 = pd.read_csv("2018_I9gem.csv")
    df_icd10 = pd.read_csv("2018_I10gem.csv")
    df_icd9_desc = pd.read_csv("CMS32_DESC_LONG_DX.csv")
    df_icd10_desc = pd.read_csv("icd10cm_codes_2018.csv")
    
    return df_icd9, df_icd9_desc, df_icd10, df_icd10_desc


def join_icd_desc(df_icd,df_desc, key: str):
    
    df = pd.merge(df_icd, df_desc,
                  left_on = "target",
                  right_on = key)
    return df

def save_icd_desc_tables(df, df_name: str):
    
    df.to_csv(df_name, index = False)
    

def add_icd_desc():
    
    df_icd9, df_icd9_desc, df_icd10, df_icd10_desc = read_tables()
    
    df9_lookup = join_icd_desc(df_icd9,
                        df_icd10_desc,
                        key = "icd10")
    
    df10_lookup = join_icd_desc(df_icd10,
                         df_icd9_desc,
                         key = "icd9")
    
    save_icd_desc_tables(df9_lookup, "icd9_gems_lookup.csv")
    save_icd_desc_tables(df10_lookup, "icd10_gems_lookup.csv")

# %%
add_icd_desc()
